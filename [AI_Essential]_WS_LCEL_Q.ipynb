# %% [markdown]
# # [AI Essential] 4일차 LCEL Example
# # 1. FewShotPrompt 기반 챗봇 구현

# %%
pip install langchain langchain_community langchain_openai streamlit pyngrok -qU
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 46.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.2 MB/s eta 0:00:00

# %%
import os

os.environ["OPENAI_API_KEY"] = ""
PYNGROK_API_KEY = ''

# %% [markdown]
# ## 0. FewShotPromt 정의

# %%
# 예제 데이터: 가전제품 고장과 대처 방법
examples = [
    {
        "question": "세탁기가 작동하지 않아요. 어떻게 해야 하나요?",
        "answer": """
1. 세탁기의 전원 케이블이 콘센트에 제대로 연결되어 있는지 확인해 주세요.
2. 세탁기의 전원 스위치가 "ON" 상태인지 확인해 주세요.
3. 세탁기의 문이 완전히 닫혀 있는지 확인해 주세요. 세탁기는 문이 열려 있을 때 작동하지 않을 수 있습니다.
4. 위의 방법으로 문제가 해결되지 않으면, 삼성 서비스 웹사이트를 방문하거나 가까운 서비스 센터에 문의하여 전문적인 점검을 받으세요.
""",
    },
    {
    "question": "냉장고가 시원하지 않아요. 어떻게 해야 하나요?",
    "answer": """
1. 냉장고의 온도 조절기가 적절히 설정되어 있는지 확인해 주세요. 너무 높은 온도 설정은 냉장고의 성능을 저하시킬 수 있습니다.
2. 냉장고의 문이 제대로 닫혀 있는지 확인해 주세요. 문이 제대로 닫히지 않으면 냉기가 새어나갈 수 있습니다.
3. 냉장고의 팬과 통풍구가 막히지 않았는지 확인해 주세요. 공기 흐름이 원활해야 냉각이 제대로 이루어집니다.
4. 냉장고의 뒷면과 측면에 먼지나 이물질이 쌓여 있는지 확인하고 청소해 주세요. 먼지가 쌓이면 냉각 성능이 저하될 수 있습니다.
5. 위의 방법으로 문제가 해결되지 않으면, 삼성 서비스 웹사이트를 방문하거나 가까운 서비스 센터에 문의하여 전문적인 점검을 받으세요.
"""
    },
    {
    "question": "에어컨이 작동하지 않아요. 어떻게 해야 하나요?",
    "answer": """
1. 에어컨의 전원 코드가 제대로 연결되어 있는지 확인해 주세요.
2. 에어컨의 전원 스위치가 "ON" 상태인지 확인해 주세요.
3. 리모컨의 배터리가 충분한지 확인하고, 배터리를 교체해 보세요.
4. 에어컨의 필터가 막히거나 더러워졌는지 확인하고 청소해 주세요.
5. 위의 방법으로 문제가 해결되지 않으면, 삼성 서비스 웹사이트를 방문하거나 가까운 서비스 센터에 문의하여 전문적인 점검을 받으세요.
"""
    }
]

# %% [markdown]
# ## 1. PromptTemplate 템플릿 정의 (예시)

# %%
from langchain_core.prompts import PromptTemplate

# one-shot 예제 프롬프트 템플릿 생성
example_prompt =

# 프롬프트 생성 후 출력
# Out:
# Question:
# 세탁기가 작동하지 않아요. 어떻게 해야 하나요?
# Answer:
#
# 1. 세탁기의 전원 케이블이 콘센트에 제대로 연결되어 있는지 확인해 주세요.
# 2. 세탁기의 전원 스위치가 "ON" 상태인지 확인해 주세요.
# 3. 세탁기의 문이 완전히 닫혀 있는지 확인해 주세요. 세탁기는 문이 열려 있을 때 작동하지 않을 수 있습니다.
# 4. 위의 방법으로 문제가 해결되지 않으면, 삼성 서비스 웹사이트를 방문하거나 가까운 서비스 센터에 문의하여 전문적인 점검을 받으세요.

# %% [markdown]
# ## 2. FewShotPromptTemplate 템플릿 정의

# %%
from langchain_core.prompts.few_shot import FewShotPromptTemplate

# few-shot 프롬프트 템플릿 생성
prompt =

question = "공기청정기를 작동해도 미세먼지 농도가 줄어들지 않아요."

# few-shot 프롬프트 생성
final_prompt =

# 최종 생성된 프롬프트를 출력
print(final_prompt)
# Out:
# Question:
# 세탁기가 작동하지 않아요. 어떻게 해야 하나요?
# Answer:
#
# 1. 세탁기의 전원 케이블이 콘센트에 제대로 연결되어 있는지 확인해 주세요.
# 2. 세탁기의 전원 스위치가 "ON" 상태인지 확인해 주세요.
# 3. 세탁기의 문이 완전히 닫혀 있는지 확인해 주세요. 세탁기는 문이 열려 있을 때 작동하지 않을 수 있습니다.
# 4. 위의 방법으로 문제가 해결되지 않으면, 삼성 서비스 웹사이트를 방문하거나 가까운 서비스 센터에 문의하여 전문적인 점검을 받으세요.
#
#
# Question:
# 냉장고가 시원하지 않아요. 어떻게 해야 하나요?
# Answer:
#
# 1. 냉장고의 온도 조절기가 적절히 설정되어 있는지 확인해 주세요. 너무 높은 온도 설정은 냉장고의 성능을 저하시킬 수 있습니다.
# 2. 냉장고의 문이 제대로 닫혀 있는지 확인해 주세요. 문이 제대로 닫히지 않으면 냉기가 새어나갈 수 있습니다.
# 3. 냉장고의 팬과 통풍구가 막히지 않았는지 확인해 주세요. 공기 흐름이 원활해야 냉각이 제대로 이루어집니다.
# 4. 냉장고의 뒷면과 측면에 먼지나 이물질이 쌓여 있는지 확인하고 청소해 주세요. 먼지가 쌓이면 냉각 성능이 저하될 수 있습니다.
# 5. 위의 방법으로 문제가 해결되지 않으면, 삼성 서비스 웹사이트를 방문하거나 가까운 서비스 센터에 문의하여 전문적인 점검을 받으세요.
#
#
# Question:
# 에어컨이 작동하지 않아요. 어떻게 해야 하나요?
# Answer:
#
# 1. 에어컨의 전원 코드가 제대로 연결되어 있는지 확인해 주세요.
# 2. 에어컨의 전원 스위치가 "ON" 상태인지 확인해 주세요.
# 3. 리모컨의 배터리가 충분한지 확인하고, 배터리를 교체해 보세요.
# 4. 에어컨의 필터가 막히거나 더러워졌는지 확인하고 청소해 주세요.
# 5. 위의 방법으로 문제가 해결되지 않으면, 삼성 서비스 웹사이트를 방문하거나 가까운 서비스 센터에 문의하여 전문적인 점검을 받으세요.
#
#
# Question:
# 공기청정기를 작동해도 미세먼지 농도가 줄어들지 않아요.
# Answer:

# %% [markdown]
# ## 3. 응답 모델 구현

# %%
from langchain_openai import ChatOpenAI

# ChatOpenAI 인스턴스를 생성하면서 모델과 파라미터를 설정.
llm =

# %% [markdown]
# ## 5. 프롬프트 테스트

# %%
# 스트리밍으로 테스트
# Out:
# 1. 공기청정기의 필터가 깨끗한지 확인해 주세요. 필터가 더러워지면 공기 청정 효과가 저하될 수 있습니다. 필요시 필터를 청소하거나 교체해 주세요.
# 2. 공기청정기의 모드 설정이 적절한지 확인해 주세요. 일반 모드 대신 강력 모드로 설정하면 미세먼지 제거에 더 효과적일 수 있습니다.
# 3. 공기청정기가 방의 크기에 맞는 모델인지 확인해 주세요. 너무 작은 용량의 공기청정기는 큰 공간에서 효과적으로 작동하지 않을 수 있습니다.
# 4. 공기청정기의 흡입구와 배출구가 막히지 않았는지 확인해 주세요. 공기 흐름이 원활해야 최적의 성능을 발휘합니다.
# 5. 위의 방법으로 문제가 해결되지 않으면, 삼성 서비스 웹사이트를 방문하거나 가까운 서비스 센터에 문의하여 전문적인 점검을 받으세요.

# %% [markdown]
# # 2. 웹 환경 FewShotPrompt기반 챗봇 구현

# %%
# %%writefile app.py
import streamlit as st
from langchain.chat_models import ChatOpenAI
from langchain_core.prompts.few_shot import FewShotPromptTemplate
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 예제 데이터: 가전제품 고장과 대처 방법
examples = [
    {
        "question": "세탁기가 작동하지 않아요. 어떻게 해야 하나요?",
        "answer": """
1. 세탁기의 전원 케이블이 콘센트에 제대로 연결되어 있는지 확인해 주세요.
2. 세탁기의 전원 스위치가 "ON" 상태인지 확인해 주세요.
3. 세탁기의 문이 완전히 닫혀 있는지 확인해 주세요. 세탁기는 문이 열려 있을 때 작동하지 않을 수 있습니다.
4. 위의 방법으로 문제가 해결되지 않으면, 삼성 서비스 웹사이트를 방문하거나 가까운 서비스 센터에 문의하여 전문적인 점검을 받으세요.
"""
    },
    {
        "question": "냉장고가 시원하지 않아요. 어떻게 해야 하나요?",
        "answer": """
1. 냉장고의 온도 조절기가 적절히 설정되어 있는지 확인해 주세요. 너무 높은 온도 설정은 냉장고의 성능을 저하시킬 수 있습니다.
2. 냉장고의 문이 제대로 닫혀 있는지 확인해 주세요. 문이 제대로 닫히지 않으면 냉기가 새어나갈 수 있습니다.
3. 냉장고의 팬과 통풍구가 막히지 않았는지 확인해 주세요. 공기 흐름이 원활해야 냉각이 제대로 이루어집니다.
4. 냉장고의 뒷면과 측면에 먼지나 이물질이 쌓여 있는지 확인하고 청소해 주세요. 먼지가 쌓이면 냉각 성능이 저하될 수 있습니다.
5. 위의 방법으로 문제가 해결되지 않으면, 삼성 서비스 웹사이트를 방문하거나 가까운 서비스 센터에 문의하여 전문적인 점검을 받으세요.
"""
    },
    {
        "question": "에어컨이 작동하지 않아요. 어떻게 해야 하나요?",
        "answer": """
1. 에어컨의 전원 코드가 제대로 연결되어 있는지 확인해 주세요.
2. 에어컨의 전원 스위치가 "ON" 상태인지 확인해 주세요.
3. 리모컨의 배터리가 충분한지 확인하고, 배터리를 교체해 보세요.
4. 에어컨의 필터가 막히거나 더러워졌는지 확인하고 청소해 주세요.
5. 위의 방법으로 문제가 해결되지 않으면, 삼성 서비스 웹사이트를 방문하거나 가까운 서비스 센터에 문의하여 전문적인 점검을 받으세요.
"""
    }
]

# one-shot 프롬프트 템플릿 생성
example_prompt =

# few-shot 프롬프트 템플릿 생성
prompt =

# 좌측 사이드바를 통해 API 키 입력받기
st.sidebar.title("API 설정")
api_key_input = st.sidebar.text_input("OpenAI API Key", type="password")

if api_key_input:
    # 입력받은 API 키를 사용하여 OpenAI 클라이언트 설정
    llm = ChatOpenAI(model_name="gpt-4o", temperature=0, api_key=api_key_input)
    chain =  prompt | llm | StrOutputParser()

    st.title("가전제품 고객지원 응답봇")

    if "openai_model" not in st.session_state:
        st.session_state["openai_model"] = "gpt-3.5-turbo"

    if "messages" not in st.session_state:
        st.session_state.messages = []

    # 이전 대화 메시지 표시
    for message in st.session_state.messages:
        with st.chat_message(message["role"]):
            st.markdown(message["content"])

    # 사용자 입력 받기
    if user_question := st.chat_input("고장 사항을 입력하세요:"):
        # 사용자 메시지 추가
        st.session_state.messages.append({"role": "user", "content": user_question})
        with st.chat_message("user"):
            st.write(user_question)

        # OpenAI API를 통해 어시스턴트 응답 받기
        with st.chat_message("assistant"):
            # 스트리밍 방식으로 응답 받기
            # 스트리밍 출력은 result = st.write_stream(스트림)
            result =

        # 어시스턴트 응답을 세션 상태에 추가
        st.session_state.messages.append({"role": "assistant", "content": result})

else:
    st.sidebar.warning("API 키를 입력하세요.")
    st.stop()  # API 키가 없으면 프로그램이 계속되지 않도록 중지
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok

# ngrok 서비스 인증
ngrok.set_auth_token(PYNGROK_API_KEY)

# app1.py 백그라운드 프로세스 실행
# !nohup streamlit run app.py --server.port 5011 &

# ngrok 터널링 실행
ngrok_tunnel = ngrok.connect(addr='5011', proto='http', bind_tls=True)

# ngrok 터널링 결과
print(' * Tunnel URL:', ngrok_tunnel.public_url)
# Out:
# nohup: appending output to 'nohup.out'
#  * Tunnel URL: https://7608-35-204-60-173.ngrok-free.app

# %%
# Streamlit 서비스 종료
# !pkill -f streamlit
# ngrok 터널링 종료
ngrok.disconnect(ngrok_tunnel.public_url)
# Out:
# WARNING:pyngrok.process.ngrok:t=2024-10-09T13:31:38+0000 lvl=warn msg="Stopping forwarder" name=http-5011-157e0fed-b977-4f6d-b472-94aaa053169e acceptErr="failed to accept connection: Listener closed"
